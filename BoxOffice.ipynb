# %%
pwd()
# Out:
# 'C:\\Projects\\OneDrive - CA Technologies\\IM Team\\Projects\\Interview\\usecases'

# %%
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
df = pd.read_csv("boxoffice/data/box_office_predictions.csv")

# %%
df.head()
# Out:
#         budget country           director   genre        gross  \
# 0  237000000.0      UK      James Cameron  Action  760507625.0
# 1  200000000.0     USA      James Cameron   Drama  658672302.0
# 2  150000000.0     USA    Colin Trevorrow  Action  652270625.0
# 3  220000000.0     USA        Joss Whedon  Action  623357910.0
# 4  185000000.0     USA  Christopher Nolan  Action  534858444.0
#
#                      name rating  runtime  score               star  \
# 0           Avatar (2009)  PG-13      162    7.8    Sam Worthington
# 1          Titanic (1997)  PG-13      194    7.8  Leonardo DiCaprio
# 2   Jurassic World (2015)  PG-13      124    7.0        Chris Pratt
# 3     The Avengers (2012)  PG-13      143    8.1  Robert Downey Jr.
# 4  The Dark Knight (2008)  PG-13      152    9.0     Christian Bale
#
#                                    studio    votes
# 0  Twentieth Century Fox Film Corporation   958400
# 1  Twentieth Century Fox Film Corporation   865551
# 2                      Universal Pictures   470625
# 3                          Marvel Studios  1069292
# 4                            Warner Bros.  1845853

# %%
df.hist(figsize=(8,7))
plt.show()

# %%
df.describe()
# Out:
#              budget         gross      runtime        score         votes
# count  6.000000e+03  6.000000e+03  6000.000000  6000.000000  6.000000e+03
# mean   2.469918e+07  3.341635e+07   106.587000     6.386383  7.188537e+04
# std    3.721710e+07  5.735205e+07    18.026885     0.994921  1.308033e+05
# min    0.000000e+00  4.410000e+02    50.000000     1.500000  2.700000e+01
# 25%    0.000000e+00  1.527796e+06    95.000000     5.800000  7.791750e+03
# 50%    1.100000e+07  1.229897e+07   102.000000     6.500000  2.660150e+04
# 75%    3.262500e+07  4.007256e+07   115.000000     7.100000  7.677475e+04
# max    3.000000e+08  7.605076e+08   366.000000     9.300000  1.868308e+06

# %%
df[df.budget==0].head()
# Out:
#      budget country          director      genre        gross  \
# 56      0.0      UK       David Yates  Adventure  295983305.0
# 207     0.0     USA       Walt Becker     Action  168273550.0
# 431     0.0     USA  John G. Avildsen     Action  115103979.0
# 553     0.0     USA       Nora Ephron     Comedy   95318203.0
# 592     0.0     USA       Tyler Perry     Comedy   90485233.0
#
#                                                   name rating  runtime  score  \
# 56   Harry Potter and the Deathly Hallows: Part 1 (...  PG-13      146    7.7
# 207                                   Wild Hogs (2007)  PG-13      100    5.9
# 431                      The Karate Kid Part II (1986)     PG      113    5.9
# 553                                     Michael (1996)     PG      105    5.7
# 592                          Madea Goes to Jail (2009)  PG-13      103    4.3
#
#                  star                         studio   votes
# 56   Daniel Radcliffe                   Warner Bros.  370003
# 207         Tim Allen            Touchstone Pictures  104657
# 431        Pat Morita  Columbia Pictures Corporation   58596
# 553     John Travolta            Turner Pictures (I)   36553
# 592       Tyler Perry       Tyler Perry Company, The   10095

# %%
df = df.loc[df.budget >0,:]

# %%
df.head()
# Out:
#         budget country           director   genre        gross  \
# 0  237000000.0      UK      James Cameron  Action  760507625.0
# 1  200000000.0     USA      James Cameron   Drama  658672302.0
# 2  150000000.0     USA    Colin Trevorrow  Action  652270625.0
# 3  220000000.0     USA        Joss Whedon  Action  623357910.0
# 4  185000000.0     USA  Christopher Nolan  Action  534858444.0
#
#                      name rating  runtime  score               star  \
# 0           Avatar (2009)  PG-13      162    7.8    Sam Worthington
# 1          Titanic (1997)  PG-13      194    7.8  Leonardo DiCaprio
# 2   Jurassic World (2015)  PG-13      124    7.0        Chris Pratt
# 3     The Avengers (2012)  PG-13      143    8.1  Robert Downey Jr.
# 4  The Dark Knight (2008)  PG-13      152    9.0     Christian Bale
#
#                                    studio    votes
# 0  Twentieth Century Fox Film Corporation   958400
# 1  Twentieth Century Fox Film Corporation   865551
# 2                      Universal Pictures   470625
# 3                          Marvel Studios  1069292
# 4                            Warner Bros.  1845853

# %%
df.describe(include='object')
# Out:
#        country     director   genre  \
# count     4089         4089    4089
# unique      42         1757      16
# top        USA  Woody Allen  Comedy
# freq      3275           26    1136
#
#                                              name rating          star  \
# count                                        4089   4089          4089
# unique                                       4089      8          1501
# top     The Magic Sword: Quest for Camelot (1998)      R  Nicolas Cage
# freq                                            1   2001            36
#
#                     studio
# count                 4089
# unique                1232
# top     Universal Pictures
# freq                   235

# %%
df[df.country=='India'].head()
# Out:
#           budget country        director      genre      gross  \
# 3511  18026148.0   India  S.S. Rajamouli     Action  6738000.0
# 3866   1000000.0   India    Ritesh Batra      Drama  4231500.0
# 3906  12000000.0   India     Karan Johar  Adventure  4018695.0
# 3974  16700000.0   India   Farhan Akhtar     Action  3680306.0
# 4131   7000000.0   India     Yash Chopra      Drama  2921738.0
#
#                                  name         rating  runtime  score  \
# 3511  Baahubali: The Beginning (2015)  Not specified      159    8.2
# 3866              The Lunchbox (2013)             PG      104    7.8
# 3906           My Name Is Khan (2010)          PG-13      165    8.0
# 3974                     Don 2 (2011)      NOT RATED      148    7.1
# 4131                Veer-Zaara (2004)      NOT RATED      192    7.9
#
#                 star                studio  votes
# 3511         Prabhas       Arka Mediaworks  81694
# 3866     Irrfan Khan  Sikhya Entertainment  37049
# 3906  Shah Rukh Khan    Dharma Productions  81484
# 3974  Shah Rukh Khan   Excel Entertainment  43362
# 4131  Shah Rukh Khan        Yash Raj Films  40041

# %%
sum(df.country=='USA')
# Out:
# 3275

# %%
df.studio.value_counts().head()
# Out:
# Universal Pictures                        235
# Warner Bros.                              231
# Paramount Pictures                        197
# Twentieth Century Fox Film Corporation    148
# New Line Cinema                           123
# Name: studio, dtype: int64

# %%
#Feature Engineering
df['profit'] = df.budget - df.gross

# %%
df.head()
# Out:
#         budget country           director   genre        gross  \
# 0  237000000.0      UK      James Cameron  Action  760507625.0
# 1  200000000.0     USA      James Cameron   Drama  658672302.0
# 2  150000000.0     USA    Colin Trevorrow  Action  652270625.0
# 3  220000000.0     USA        Joss Whedon  Action  623357910.0
# 4  185000000.0     USA  Christopher Nolan  Action  534858444.0
#
#                      name rating  runtime  score               star  \
# 0           Avatar (2009)  PG-13      162    7.8    Sam Worthington
# 1          Titanic (1997)  PG-13      194    7.8  Leonardo DiCaprio
# 2   Jurassic World (2015)  PG-13      124    7.0        Chris Pratt
# 3     The Avengers (2012)  PG-13      143    8.1  Robert Downey Jr.
# 4  The Dark Knight (2008)  PG-13      152    9.0     Christian Bale
#
#                                    studio    votes       profit
# 0  Twentieth Century Fox Film Corporation   958400 -523507625.0
# 1  Twentieth Century Fox Film Corporation   865551 -458672302.0
# 2                      Universal Pictures   470625 -502270625.0
# 3                          Marvel Studios  1069292 -403357910.0
# 4                            Warner Bros.  1845853 -349858444.0

# %%
df.describe(include='object')
# Out:
#        country     director   genre  \
# count     4089         4089    4089
# unique      42         1757      16
# top        USA  Woody Allen  Comedy
# freq      3275           26    1136
#
#                                              name rating          star  \
# count                                        4089   4089          4089
# unique                                       4089      8          1501
# top     The Magic Sword: Quest for Camelot (1998)      R  Nicolas Cage
# freq                                            1   2001            36
#
#                     studio
# count                 4089
# unique                1232
# top     Universal Pictures
# freq                   235

# %%
studio_counts = df.studio.value_counts()

# Tiers for sparser studios
one_timers = studio_counts[studio_counts <= 1].index
three_timers = studio_counts[(studio_counts > 1) & (studio_counts <= 3)].index
five_timers = studio_counts[(studio_counts > 3) & (studio_counts <= 5)].index
ten_timers = studio_counts[(studio_counts > 5) & (studio_counts <= 10)].index

df['studio'].replace(one_timers,'One Timer',inplace=True)
df['studio'].replace(three_timers,'Three Timer',inplace=True)
df['studio'].replace(five_timers,'Five Timer',inplace =True)
df['studio'].replace(ten_timers,'Ten Timer',inplace=True)

# %%
df
# Out:
#            budget    country             director      genre        gross  \
# 0     237000000.0         UK        James Cameron     Action  760507625.0
# 1     200000000.0        USA        James Cameron      Drama  658672302.0
# 2     150000000.0        USA      Colin Trevorrow     Action  652270625.0
# 3     220000000.0        USA          Joss Whedon     Action  623357910.0
# 4     185000000.0        USA    Christopher Nolan     Action  534858444.0
# 5     200000000.0        USA       Gareth Edwards     Action  532177324.0
# 6     115000000.0        USA         George Lucas     Action  474544677.0
# 7     250000000.0        USA          Joss Whedon     Action  459005868.0
# 8     250000000.0         UK    Christopher Nolan     Action  448139099.0
# 9     150000000.0        USA       Andrew Adamson  Animation  436471036.0
# 10    130000000.0        USA     Francis Lawrence     Action  424668047.0
# 11    225000000.0        USA       Gore Verbinski     Action  423315812.0
# 12    200000000.0        USA          Lee Unkrich  Animation  415004880.0
# 13    200000000.0      China          Shane Black     Action  409013994.0
# 14    250000000.0        USA        Anthony Russo     Action  408084349.0
# 15     78000000.0        USA            Gary Ross  Adventure  408010692.0
# 16    139000000.0        USA            Sam Raimi     Action  403706375.0
# 17     63000000.0        USA     Steven Spielberg  Adventure  402453882.0
# 18    200000000.0        USA          Michael Bay     Action  402111870.0
# 19    150000000.0        USA           Chris Buck  Animation  400738009.0
# 20    125000000.0        USA          David Yates  Adventure  381011219.0
# 21     94000000.0        USA       Andrew Stanton  Animation  380843261.0
# 22    113000000.0        USA         George Lucas     Action  380262555.0
# 23    200000000.0        USA            Sam Raimi     Action  373585825.0
# 24     30000000.0        USA           Mel Gibson      Drama  370782930.0
# 25     76000000.0        USA        Pierre Coffin  Animation  368061265.0
# 26    175000000.0         UK          Jon Favreau  Adventure  364001123.0
# 27     58000000.0        USA           Tim Miller     Action  363070709.0
# 28    175000000.0        USA          Pete Docter  Animation  356461711.0
# 29    190000000.0        USA            James Wan     Action  353007020.0
# ...           ...        ...                  ...        ...          ...
# 5926    4000000.0     Brazil         José Padilha     Action       8060.0
# 5927    2000000.0  Australia        Justin Kurzel  Biography       8012.0
# 5929   10000000.0         UK          Guy Ritchie     Comedy       7876.0
# 5930    2500000.0    Denmark       Lars von Trier     Comedy       7235.0
# 5931      20000.0        USA           Ben Coccio      Drama       7221.0
# 5932   25000000.0        USA      William Monahan      Crime       6911.0
# 5933   25000000.0        USA         Simon Hunter     Action       6820.0
# 5934    8500000.0         UK          Eran Creevy     Action       6787.0
# 5937    1200000.0        USA         James Bolton      Drama       6319.0
# 5943    5000000.0        USA       John Stockwell  Biography       5565.0
# 5946   10000000.0        USA      Matthew Chapman      Drama       5176.0
# 5947    3000000.0        USA  Francesca Gregorini      Drama       5005.0
# 5949   10000000.0         UK          John Landis     Comedy       4833.0
# 5951    7000000.0      Spain         Jorge Dorado      Drama       4288.0
# 5953    6000000.0        USA           Lance Daly      Drama       4106.0
# 5960    8000000.0        USA         Mitch Glazer      Drama       3669.0
# 5961   10000000.0      Spain   Álex de la Iglesia      Crime       3607.0
# 5962   47000000.0    Belgium     Jaco Van Dormael      Drama       3600.0
# 5963    1500000.0     Canada       Bruce McDonald    Fantasy       3478.0
# 5964    2000000.0        USA        Stuart Gordon     Horror       3331.0
# 5968   11500000.0        USA            Rod Lurie      Crime       3045.0
# 5969   16000000.0        USA       Amy Heckerling     Comedy       2964.0
# 5971    2500000.0        USA      Stephen Elliott      Drama       2760.0
# 5975    5000000.0     Canada         John Fawcett      Drama       2554.0
# 5981    3000000.0        USA         David Brooks     Horror       2034.0
# 5983    7000000.0        USA         Aaron Harvey     Action       1887.0
# 5987    6000000.0        USA         Tommy Wiseau      Drama       1800.0
# 5988   10000000.0        USA       Richard Harrah   Thriller       1785.0
# 5989   12000000.0     Canada         David Weaver      Crime       1744.0
# 5991     500000.0        USA        Lloyd Kaufman     Comedy       1434.0
#
#                                                    name     rating  runtime  \
# 0                                         Avatar (2009)      PG-13      162
# 1                                        Titanic (1997)      PG-13      194
# 2                                 Jurassic World (2015)      PG-13      124
# 3                                   The Avengers (2012)      PG-13      143
# 4                                The Dark Knight (2008)      PG-13      152
# 5                                      Rogue One (2016)      PG-13      133
# 6      Star Wars: Episode I - The Phantom Menace (1999)         PG      136
# 7                        Avengers: Age of Ultron (2015)      PG-13      141
# 8                          The Dark Knight Rises (2012)      PG-13      164
# 9                                        Shrek 2 (2004)         PG       93
# 10               The Hunger Games: Catching Fire (2013)      PG-13      146
# 11    Pirates of the Caribbean: Dead Man's Chest (2006)      PG-13      151
# 12                                   Toy Story 3 (2010)          G      103
# 13                                    Iron Man 3 (2013)      PG-13      130
# 14                    Captain America: Civil War (2016)      PG-13      147
# 15                              The Hunger Games (2012)      PG-13      142
# 16                                    Spider-Man (2002)      PG-13      121
# 17                                 Jurassic Park (1993)      PG-13      127
# 18           Transformers: Revenge of the Fallen (2009)      PG-13      150
# 19                                        Frozen (2013)         PG      102
# 20    Harry Potter and the Deathly Hallows: Part 2 (...      PG-13      130
# 21                                  Finding Nemo (2003)          G      100
# 22    Star Wars: Episode III - Revenge of the Sith (...      PG-13      140
# 23                                  Spider-Man 2 (2004)      PG-13      127
# 24                     The Passion of the Christ (2004)          R      127
# 25                               Despicable Me 2 (2013)         PG       98
# 26                               The Jungle Book (2016)         PG      106
# 27                                      Deadpool (2016)          R      108
# 28                                    Inside Out (2015)         PG       95
# 29                                     Furious 7 (2015)      PG-13      137
# ...                                                 ...        ...      ...
# 5926                                 Elite Squad (2007)          R      115
# 5927                        The Snowtown Murders (2011)  NOT RATED      119
# 5929                                  Swept Away (2002)          R       89
# 5930                                 Los idiotas (1998)          R      117
# 5931                                    Zero Day (2003)    UNRATED       92
# 5932                            London Boulevard (2010)          R      103
# 5933                           Mutant Chronicles (2008)          R      111
# 5934                        Welcome to the Punch (2013)          R       99
# 5937                                   Dream Boy (2008)          R       90
# 5943                                Kid Cannabis (2014)  NOT RATED      110
# 5946                                   The Ledge (2011)          R      100
# 5947                                 Tanner Hall (2009)          R       96
# 5949                              Burke and Hare (2010)          R       91
# 5951                                        Anna (2013)          R       99
# 5953                             The Good Doctor (2011)      PG-13       91
# 5960                                Passion Play (2010)          R       94
# 5961                          The Oxford Murders (2008)          R      104
# 5962                                  Mr. Nobody (2009)          R      141
# 5963                                   Pontypool (2008)  NOT RATED       93
# 5964                    The Pit and the Pendulum (1991)          R       97
# 5968                       Nothing But the Truth (2008)          R      108
# 5969                                       Vamps (2012)      PG-13       92
# 5971                                About Cherry (2012)          R       98
# 5975                                       Feroz (2000)    UNRATED      108
# 5981                                         ATM (2012)          R       90
# 5983                                   Catch .44 (2011)          R       94
# 5987                                    The Room (2003)          R       99
# 5988                                  The Canyon (2009)          R      100
# 5989                               The Samaritan (2012)          R       90
# 5991                               Terror Firmer (1999)          R      114
#
#       score                   star                                  studio  \
# 0       7.8        Sam Worthington  Twentieth Century Fox Film Corporation
# 1       7.8      Leonardo DiCaprio  Twentieth Century Fox Film Corporation
# 2       7.0            Chris Pratt                      Universal Pictures
# 3       8.1      Robert Downey Jr.                               Ten Timer
# 4       9.0         Christian Bale                            Warner Bros.
# 5       7.9         Felicity Jones                              Five Timer
# 6       6.5          Ewan McGregor                              Five Timer
# 7       7.4      Robert Downey Jr.                               Ten Timer
# 8       8.4         Christian Bale                            Warner Bros.
# 9       7.2             Mike Myers                              DreamWorks
# 10      7.6      Jennifer Lawrence                              Five Timer
# 11      7.3            Johnny Depp                    Walt Disney Pictures
# 12      8.3              Tom Hanks                    Walt Disney Pictures
# 13      7.2      Robert Downey Jr.                               Ten Timer
# 14      7.9            Chris Evans                               Ten Timer
# 15      7.2      Jennifer Lawrence                               Lionsgate
# 16      7.3          Tobey Maguire           Columbia Pictures Corporation
# 17      8.1              Sam Neill                      Universal Pictures
# 18      6.0           Shia LaBeouf                              DreamWorks
# 19      7.5           Kristen Bell                               Ten Timer
# 20      8.1       Daniel Radcliffe                            Warner Bros.
# 21      8.1          Albert Brooks                               Ten Timer
# 22      7.6     Hayden Christensen                              Five Timer
# 23      7.3          Tobey Maguire           Columbia Pictures Corporation
# 24      7.2           Jim Caviezel                             Three Timer
# 25      7.4           Steve Carell                      Universal Pictures
# 26      7.5             Neel Sethi                               One Timer
# 27      8.0          Ryan Reynolds  Twentieth Century Fox Film Corporation
# 28      8.2            Amy Poehler                               Ten Timer
# 29      7.2             Vin Diesel                      Universal Pictures
# ...     ...                    ...                                     ...
# 5926    8.1           Wagner Moura                               One Timer
# 5927    6.6         Lucas Pittaway                               One Timer
# 5929    3.6                Madonna                             Screen Gems
# 5930    6.9        Bodil Jørgensen                              Five Timer
# 5931    7.3          Cal Robertson                               One Timer
# 5932    6.2          Colin Farrell                              Five Timer
# 5933    5.2            Thomas Jane                             Three Timer
# 5934    6.1           James McAvoy                               Ten Timer
# 5937    6.2         Stephan Bender                               One Timer
# 5943    6.4  Jonathan Daniel Brown                               One Timer
# 5946    6.6         Charlie Hunnam                               One Timer
# 5947    5.9            Rooney Mara                               One Timer
# 5949    6.2            Bill Bailey                               One Timer
# 5951    6.5            Mark Strong                               One Timer
# 5953    5.6          Orlando Bloom                               One Timer
# 5960    5.0          Mickey Rourke                             Three Timer
# 5961    6.1            Elijah Wood                             Three Timer
# 5962    7.9             Jared Leto                               One Timer
# 5963    6.7       Stephen McHattie                               One Timer
# 5964    6.1        Lance Henriksen                               One Timer
# 5968    7.2        Kate Beckinsale                               One Timer
# 5969    5.1     Alicia Silverstone                               One Timer
# 5971    4.8         Ashley Hinshaw                             Three Timer
# 5975    6.8          Emily Perkins                               One Timer
# 5981    4.7              Alice Eve                              Five Timer
# 5983    4.6          Malin Akerman                             Three Timer
# 5987    3.6           Tommy Wiseau                               One Timer
# 5988    5.9            Eion Bailey                               One Timer
# 5989    5.6      Samuel L. Jackson                               One Timer
# 5991    6.3            Will Keenan                               One Timer
#
#         votes       profit
# 0      958400 -523507625.0
# 1      865551 -458672302.0
# 2      470625 -502270625.0
# 3     1069292 -403357910.0
# 4     1845853 -349858444.0
# 5      366803 -332177324.0
# 6      587113 -359544677.0
# 7      540298 -209005868.0
# 8     1259109 -198139099.0
# 9      344003 -286471036.0
# 10     538184 -294668047.0
# 11     570136 -198315812.0
# 12     605687 -215004880.0
# 13     608085 -209013994.0
# 14     444625 -158084349.0
# 15     751734 -330010692.0
# 16     589626 -264706375.0
# 17     687813 -339453882.0
# 18     345057 -202111870.0
# 19     466249 -250738009.0
# 20     611380 -256011219.0
# 21     774469 -286843261.0
# 22     572131 -267262555.0
# 23     453462 -173585825.0
# 24     189777 -340782930.0
# 25     315528 -292061265.0
# 26     209805 -189001123.0
# 27     670760 -305070709.0
# 28     441406 -181461711.0
# 29     311380 -163007020.0
# ...       ...          ...
# 5926    87062    3991940.0
# 5927    14532    1991988.0
# 5929    13793    9992124.0
# 5930    25795    2492765.0
# 5931     3611      12779.0
# 5932    42629   24993089.0
# 5933    24304   24993180.0
# 5934    28873    8493213.0
# 5937     3259    1193681.0
# 5943     8258    4994435.0
# 5946    16661    9994824.0
# 5947     2557    2994995.0
# 5949    17304    9995167.0
# 5951    16869    6995712.0
# 5953     5559    5995894.0
# 5960     7569    7996331.0
# 5961    24381    9996393.0
# 5962   173821   46996400.0
# 5963    24646    1496522.0
# 5964     3256    1996669.0
# 5968    32392   11496955.0
# 5969     8145   15997036.0
# 5971     8630    2497240.0
# 5975    35552    4997446.0
# 5981    20233    2997966.0
# 5983    15308    6998113.0
# 5987    40496    5998200.0
# 5988     3465    9998215.0
# 5989     8373   11998256.0
# 5991     4239     498566.0
#
# [4089 rows x 13 columns]

# %%
star_counts = df.star.value_counts()

# Tiers for sparser stars
one_timers = star_counts[star_counts <= 1].index
three_timers = star_counts[(star_counts > 1) & (star_counts <= 3)].index
five_timers = star_counts[(star_counts > 3) & (star_counts <= 5)].index
ten_timers = star_counts[(star_counts > 5) & (star_counts <= 10)].index

df['star'].replace(one_timers,'One Timer',inplace=True)
df['star'].replace(three_timers,'Three Timer',inplace=True)
df['star'].replace(five_timers,'Five Timer',inplace =True)
df['star'].replace(ten_timers,'Ten Timer',inplace=True)

# %%
director_counts = df.director.value_counts()

# Tiers for sparser directors
one_timers = director_counts[director_counts <= 1].index
three_timers = director_counts[(director_counts > 1) & (director_counts <= 3)].index
five_timers = director_counts[(director_counts > 3) & (director_counts <= 5)].index
ten_timers = director_counts[(director_counts > 5) & (director_counts <= 10)].index

df['director'].replace(one_timers,'One Timer',inplace=True)
df['director'].replace(three_timers,'Three Timer',inplace=True)
df['director'].replace(five_timers,'Five Timer',inplace =True)
df['director'].replace(ten_timers,'Ten Timer',inplace=True)

# %%
country_counts = df.country.value_counts()

# Tiers for sparser countrys
one_timers = country_counts[country_counts <= 1].index
three_timers = country_counts[(country_counts > 1) & (country_counts <= 3)].index
five_timers = country_counts[(country_counts > 3) & (country_counts <= 5)].index
ten_timers = country_counts[(country_counts > 5) & (country_counts <= 10)].index

df['country'].replace(one_timers,'One Timer',inplace=True)
df['country'].replace(three_timers,'Three Timer',inplace=True)
df['country'].replace(five_timers,'Five Timer',inplace =True)
df['country'].replace(ten_timers,'Ten Timer',inplace=True)

# %%
genre_counts = df.genre.value_counts()

# Tiers for sparser genres
one_timers = genre_counts[genre_counts <= 1].index
three_timers = genre_counts[(genre_counts > 1) & (genre_counts <= 3)].index
five_timers = genre_counts[(genre_counts > 3) & (genre_counts <= 5)].index
ten_timers = genre_counts[(genre_counts > 5) & (genre_counts <= 10)].index

df['genre'].replace(one_timers,'One Timer',inplace=True)
df['genre'].replace(three_timers,'Three Timer',inplace=True)
df['genre'].replace(five_timers,'Five Timer',inplace =True)
df['genre'].replace(ten_timers,'Ten Timer',inplace=True)

# %%
df.rating.value_counts()
# Out:
# R                2001
# PG-13            1372
# PG                562
# G                  90
# NOT RATED          36
# UNRATED            15
# NC-17               9
# Not specified       4
# Name: rating, dtype: int64

# %%
df['rating'].replace(['NOT RATED','UNRATED','Not specified'],'NR',inplace=True)

# %%
def extract_age(s, today=2014):
    return today - int(s[-5:-1])

# %%
extract_age('The Avengers (2012)')
# Out:
# 2

# %%
df['age'] = df.name.apply(extract_age)

# %%
df.describe()
# Out:
#              budget         gross      runtime        score         votes  \
# count  4.089000e+03  4.089000e+03  4089.000000  4089.000000  4.089000e+03
# mean   3.624238e+07  4.582013e+07   107.677427     6.370311  9.631312e+04
# std    4.017648e+07  6.516885e+07    17.920415     0.999816  1.495938e+05
# min    6.000000e+03  1.434000e+03    69.000000     1.500000  1.830000e+02
# 25%    1.000000e+07  6.166819e+06    96.000000     5.800000  1.623300e+04
# 50%    2.300000e+07  2.397974e+07   104.000000     6.400000  4.423200e+04
# 75%    4.700000e+07  5.738661e+07   117.000000     7.100000  1.117320e+05
# max    3.000000e+08  7.605076e+08   280.000000     9.300000  1.868308e+06
#
#              profit          age
# count  4.089000e+03  4089.000000
# mean  -9.577745e+06    11.515285
# std    4.764291e+07     8.472635
# min   -5.235076e+08    -2.000000
# 25%   -1.964034e+07     4.000000
# 50%    1.648840e+05    11.000000
# 75%    1.116525e+07    18.000000
# max    1.769219e+08    28.000000

# %%
df[['score','votes','profit']].corr()
# Out:
#            score     votes    profit
# score   1.000000  0.469748 -0.249742
# votes   0.469748  1.000000 -0.500129
# profit -0.249742 -0.500129  1.000000

# %%
df[['score','votes','profit','budget']].corr()
# Out:
#            score     votes    profit    budget
# score   1.000000  0.469748 -0.249742  0.067490
# votes   0.469748  1.000000 -0.500129  0.452685
# profit -0.249742 -0.500129  1.000000 -0.094817
# budget  0.067490  0.452685 -0.094817  1.000000

# %% [markdown]
# <h1>Machine Learning</h1>

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# %%
#create a base table 

abt = pd.get_dummies(df.drop(['score','votes','name','gross'],axis=1))

# %%
train=abt[abt.age>=0]
test = abt[abt.age<=0]

y_train = train.profit
x_train = train.drop('profit',axis =1)

y_test = test.profit
x_test = test.drop('profit',axis =1)

# %%
# Train a basic random forest model
rf = RandomForestRegressor(random_state=1234)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=1234, verbose=0, warm_start=False)

# %%
pred = rf.predict(x_test)

# %%
sns.jointplot(y_test,pred,kind='reg')
plt.xlabel('Actual Profit')
plt.ylabel('Predicted Profit')
plt.show()

# %%
r2_score(y_test,pred)
# Out:
# 0.24140064765833913

# %%
def plot_feature_importances(columns, feature_importances, show_top_n=10):
    feats = dict( zip(columns, feature_importances) )
    imp = pd.DataFrame.from_dict(feats, orient='index').rename(columns={0: 'Gini-importance'})
    imp.sort_values(by='Gini-importance').tail(show_top_n).plot(kind='barh', figsize=(8,8))
    plt.show()

# %%
plot_feature_importances(x_train.columns,rf.feature_importances_)

# %% [markdown]
# <h2>Screening which has scores</h2>

# %%
abt_ps = pd.get_dummies(df.drop(['gross','name','votes'],axis =1))

# %%
train = abt_ps[abt_ps.age >= 0]
test = abt_ps[abt_ps.age <= 0]

y_train = train.profit
x_train = train.drop('profit',axis =1)

y_test = test.profit
x_test = test.drop('profit',axis =1)

# %%
rf=RandomForestRegressor(random_state=1234)
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=1234, verbose=0, warm_start=False)

# %%
predict = rf.predict(x_test)

# %%
r2_score(y_test,pred)
# Out:
# 0.24140064765833913

# %%
sns.jointplot(y_test, pred, kind='reg')
plt.xlabel('Actual Profit')
plt.ylabel('Predicted Profit')
plt.show()

# %%
plot_feature_importances(x_train.columns, rf.feature_importances_)
